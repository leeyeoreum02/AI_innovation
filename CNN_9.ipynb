# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime


mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)

print()
print("train.num = ", mnist.train.num_examples)
print("test.num = ", mnist.test.num_examples)
print("validation_num = ", mnist.validation.num_examples)
# Out:
# WARNING:tensorflow:From <ipython-input-2-146c2c6b42db>:7: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
# train.num =  55000
# test.num =  10000
# validation_num =  5000

# %%
learning_rate = 1e-3
epochs = 30
batch_size = 100

# %%
X = tf.placeholder(tf.float32, [None, 784])

T = tf.placeholder(tf.float32, [None, 10])

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])

# %%
W2 = tf.Variable(tf.random_normal([3, 3, 1, 32], stddev=0.01))
b2 = tf.Variable(tf.random_normal([32]))

C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

Z2 = tf.nn.relu(C2 + b2)

A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
W3 = tf.Variable(tf.random_normal([3, 3, 32, 64], stddev=0.01))
b3 = tf.Variable(tf.random_normal([64]))

C3 = tf.nn.conv2d(A2, W3, strides=[1, 1, 1, 1], padding='SAME')

Z3 = tf.nn.relu(C3 + b3)

A3 = P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
W4 = tf.Variable(tf.random_normal([3, 3, 64, 128], stddev=0.01))
b4 = tf.Variable(tf.random_normal([128]))

C4 = tf.nn.conv2d(A3, W4, strides=[1, 1, 1, 1], padding='SAME')

Z4 = tf.nn.relu(C4 + b4)

A4 = P4 = tf.nn.max_pool(Z4, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
A4_flat = P4_flat = tf.reshape(A4, [-1, 4*4*128])

# %%
W5 = tf.Variable(tf.random_normal([4*4*128, 10], stddev=0.01))
b5 = tf.Variable(tf.random_normal([10]))

Z5 = logits = tf.matmul(A4_flat, W5) + b5

y = A5 = tf.nn.softmax(Z5)

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z5, labels=T))

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
predicted_val = tf.equal(tf.argmax(A5, 1), tf.argmax(T, 1))

accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# %%
with tf.Session() as sess:
  
  sess.run(tf.global_variables_initializer())

  start_time = datetime.now()

  for i in range(epochs):

    total_batch = int(mnist.train.num_examples / batch_size)

    for step in range(total_batch):

      batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)

      loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})

      if step % 100 == 0:
        print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)

  end_time = datetime.now()

  print("\nelapsed time = ", end_time - start_time)

  test_x_data = mnist.test.images
  test_t_data = mnist.test.labels

  accuracy_val = sess.run(accuracy, feed_dict={X: test_x_data, T: test_t_data})

  print("\nAccuracy = ", accuracy_val)
# Out:
# epochs =  0 , step =  0 , loss_val =  2.3102005
# epochs =  0 , step =  100 , loss_val =  2.2967005
# epochs =  0 , step =  200 , loss_val =  2.2810283
# epochs =  0 , step =  300 , loss_val =  1.7184997
# epochs =  0 , step =  400 , loss_val =  1.7000242
# epochs =  0 , step =  500 , loss_val =  1.7608559
# epochs =  1 , step =  0 , loss_val =  1.6822783
# epochs =  1 , step =  100 , loss_val =  1.6308881
# epochs =  1 , step =  200 , loss_val =  1.6371568
# epochs =  1 , step =  300 , loss_val =  1.6695693
# epochs =  1 , step =  400 , loss_val =  1.5770285
# epochs =  1 , step =  500 , loss_val =  1.5712547
# epochs =  2 , step =  0 , loss_val =  1.5450102
# epochs =  2 , step =  100 , loss_val =  1.5259012
# epochs =  2 , step =  200 , loss_val =  1.5862725
# epochs =  2 , step =  300 , loss_val =  1.5410511
# epochs =  2 , step =  400 , loss_val =  1.5564554
# epochs =  2 , step =  500 , loss_val =  1.5458076
# epochs =  3 , step =  0 , loss_val =  1.5728987
# epochs =  3 , step =  100 , loss_val =  1.6045532
# epochs =  3 , step =  200 , loss_val =  1.52688
# epochs =  3 , step =  300 , loss_val =  1.5938419
# epochs =  3 , step =  400 , loss_val =  1.586852
# epochs =  3 , step =  500 , loss_val =  1.590109
# epochs =  4 , step =  0 , loss_val =  1.6102253
# epochs =  4 , step =  100 , loss_val =  1.5296426
# epochs =  4 , step =  200 , loss_val =  1.5756613
# epochs =  4 , step =  300 , loss_val =  1.5801325
# epochs =  4 , step =  400 , loss_val =  1.5604641
# epochs =  4 , step =  500 , loss_val =  1.556578
# epochs =  5 , step =  0 , loss_val =  1.6108656
# epochs =  5 , step =  100 , loss_val =  1.559872
# epochs =  5 , step =  200 , loss_val =  1.5316887
# epochs =  5 , step =  300 , loss_val =  1.5714514
# epochs =  5 , step =  400 , loss_val =  1.5731726
# epochs =  5 , step =  500 , loss_val =  1.5981447
# epochs =  6 , step =  0 , loss_val =  1.5633752
# epochs =  6 , step =  100 , loss_val =  1.5130076
# epochs =  6 , step =  200 , loss_val =  1.6373488
# epochs =  6 , step =  300 , loss_val =  1.5095297
# epochs =  6 , step =  400 , loss_val =  1.5162811
# epochs =  6 , step =  500 , loss_val =  1.4841892
# epochs =  7 , step =  0 , loss_val =  1.4776813
# epochs =  7 , step =  100 , loss_val =  1.4737004
# epochs =  7 , step =  200 , loss_val =  1.4739273
# epochs =  7 , step =  300 , loss_val =  1.4649886
# epochs =  7 , step =  400 , loss_val =  1.4730768
# epochs =  7 , step =  500 , loss_val =  1.4716104
# epochs =  8 , step =  0 , loss_val =  1.4719009
# epochs =  8 , step =  100 , loss_val =  1.4629986
# epochs =  8 , step =  200 , loss_val =  1.468593
# epochs =  8 , step =  300 , loss_val =  1.4796042
# epochs =  8 , step =  400 , loss_val =  1.4835852
# epochs =  8 , step =  500 , loss_val =  1.4849185
# epochs =  9 , step =  0 , loss_val =  1.4714068
# epochs =  9 , step =  100 , loss_val =  1.4652548
# epochs =  9 , step =  200 , loss_val =  1.5160632
# epochs =  9 , step =  300 , loss_val =  1.4711113
# epochs =  9 , step =  400 , loss_val =  1.4709564
# epochs =  9 , step =  500 , loss_val =  1.4713032
# epochs =  10 , step =  0 , loss_val =  1.4623004
# epochs =  10 , step =  100 , loss_val =  1.4729064
# epochs =  10 , step =  200 , loss_val =  1.4611777
# epochs =  10 , step =  300 , loss_val =  1.4925274
# epochs =  10 , step =  400 , loss_val =  1.4806906
# epochs =  10 , step =  500 , loss_val =  1.4819278
# epochs =  11 , step =  0 , loss_val =  1.4814022
# epochs =  11 , step =  100 , loss_val =  1.4699956
# epochs =  11 , step =  200 , loss_val =  1.4903703
# epochs =  11 , step =  300 , loss_val =  1.4778607
# epochs =  11 , step =  400 , loss_val =  1.4611697
# epochs =  11 , step =  500 , loss_val =  1.4738898
# epochs =  12 , step =  0 , loss_val =  1.4711585
# epochs =  12 , step =  100 , loss_val =  1.4923325
# epochs =  12 , step =  200 , loss_val =  1.4716083
# epochs =  12 , step =  300 , loss_val =  1.4819152
# epochs =  12 , step =  400 , loss_val =  1.4708487
# epochs =  12 , step =  500 , loss_val =  1.5076114
# epochs =  13 , step =  0 , loss_val =  1.5337229
# epochs =  13 , step =  100 , loss_val =  1.4612167
# epochs =  13 , step =  200 , loss_val =  1.4713106
# epochs =  13 , step =  300 , loss_val =  1.4706842
# epochs =  13 , step =  400 , loss_val =  1.467424
# epochs =  13 , step =  500 , loss_val =  1.4937286
# epochs =  14 , step =  0 , loss_val =  1.4619894
# epochs =  14 , step =  100 , loss_val =  1.4616159
# epochs =  14 , step =  200 , loss_val =  1.4799173
# epochs =  14 , step =  300 , loss_val =  1.4712708
# epochs =  14 , step =  400 , loss_val =  1.4612879
# epochs =  14 , step =  500 , loss_val =  1.4891473
# epochs =  15 , step =  0 , loss_val =  1.4611722
# epochs =  15 , step =  100 , loss_val =  1.4676158
# epochs =  15 , step =  200 , loss_val =  1.4619193
# epochs =  15 , step =  300 , loss_val =  1.4745505
# epochs =  15 , step =  400 , loss_val =  1.4711504
# epochs =  15 , step =  500 , loss_val =  1.4945266
# epochs =  16 , step =  0 , loss_val =  1.4618673
# epochs =  16 , step =  100 , loss_val =  1.4613174
# epochs =  16 , step =  200 , loss_val =  1.4612812
# epochs =  16 , step =  300 , loss_val =  1.5027213
# epochs =  16 , step =  400 , loss_val =  1.4636875
# epochs =  16 , step =  500 , loss_val =  1.4708024
# epochs =  17 , step =  0 , loss_val =  1.4696345
# epochs =  17 , step =  100 , loss_val =  1.4711509
# epochs =  17 , step =  200 , loss_val =  1.4712361
# epochs =  17 , step =  300 , loss_val =  1.4761276
# epochs =  17 , step =  400 , loss_val =  1.4633873
# epochs =  17 , step =  500 , loss_val =  1.4636613
# epochs =  18 , step =  0 , loss_val =  1.4794533
# epochs =  18 , step =  100 , loss_val =  1.4710242
# epochs =  18 , step =  200 , loss_val =  1.4736087
# epochs =  18 , step =  300 , loss_val =  1.4697809
# epochs =  18 , step =  400 , loss_val =  1.4611771
# epochs =  18 , step =  500 , loss_val =  1.4668012
# epochs =  19 , step =  0 , loss_val =  1.4714019
# epochs =  19 , step =  100 , loss_val =  1.4627556
# epochs =  19 , step =  200 , loss_val =  1.4611865
# epochs =  19 , step =  300 , loss_val =  1.4711574
# epochs =  19 , step =  400 , loss_val =  1.4630847
# epochs =  19 , step =  500 , loss_val =  1.4722867
# epochs =  20 , step =  0 , loss_val =  1.4711614
# epochs =  20 , step =  100 , loss_val =  1.4611539
# epochs =  20 , step =  200 , loss_val =  1.4647063
# epochs =  20 , step =  300 , loss_val =  1.4620013
# epochs =  20 , step =  400 , loss_val =  1.4611869
# epochs =  20 , step =  500 , loss_val =  1.4612793
# epochs =  21 , step =  0 , loss_val =  1.4611508
# epochs =  21 , step =  100 , loss_val =  1.4611937
# epochs =  21 , step =  200 , loss_val =  1.4611502
# epochs =  21 , step =  300 , loss_val =  1.4710513
# epochs =  21 , step =  400 , loss_val =  1.4803455
# epochs =  21 , step =  500 , loss_val =  1.4700083
# epochs =  22 , step =  0 , loss_val =  1.4908264
# epochs =  22 , step =  100 , loss_val =  1.4748555
# epochs =  22 , step =  200 , loss_val =  1.4611505
# epochs =  22 , step =  300 , loss_val =  1.4743447
# epochs =  22 , step =  400 , loss_val =  1.4711331
# epochs =  22 , step =  500 , loss_val =  1.4613575
# epochs =  23 , step =  0 , loss_val =  1.461155
# epochs =  23 , step =  100 , loss_val =  1.4714339
# epochs =  23 , step =  200 , loss_val =  1.4714613
# epochs =  23 , step =  300 , loss_val =  1.471149
# epochs =  23 , step =  400 , loss_val =  1.4688267
# epochs =  23 , step =  500 , loss_val =  1.4711502
# epochs =  24 , step =  0 , loss_val =  1.4632388
# epochs =  24 , step =  100 , loss_val =  1.4709195
# epochs =  24 , step =  200 , loss_val =  1.4689622
# epochs =  24 , step =  300 , loss_val =  1.471336
# epochs =  24 , step =  400 , loss_val =  1.4813904
# epochs =  24 , step =  500 , loss_val =  1.4758896
# epochs =  25 , step =  0 , loss_val =  1.4611521
# epochs =  25 , step =  100 , loss_val =  1.4811609
# epochs =  25 , step =  200 , loss_val =  1.4684372
# epochs =  25 , step =  300 , loss_val =  1.4706321
# epochs =  25 , step =  400 , loss_val =  1.4699475
# epochs =  25 , step =  500 , loss_val =  1.4812411
# epochs =  26 , step =  0 , loss_val =  1.4619074
# epochs =  26 , step =  100 , loss_val =  1.4611505
# epochs =  26 , step =  200 , loss_val =  1.4711572
# epochs =  26 , step =  300 , loss_val =  1.4612573
# epochs =  26 , step =  400 , loss_val =  1.4615533
# epochs =  26 , step =  500 , loss_val =  1.4774417
# epochs =  27 , step =  0 , loss_val =  1.4712045
# epochs =  27 , step =  100 , loss_val =  1.4715102
# epochs =  27 , step =  200 , loss_val =  1.481147
# epochs =  27 , step =  300 , loss_val =  1.4614508
# epochs =  27 , step =  400 , loss_val =  1.461157
# epochs =  27 , step =  500 , loss_val =  1.4808393
# epochs =  28 , step =  0 , loss_val =  1.4689106
# epochs =  28 , step =  100 , loss_val =  1.4611545
# epochs =  28 , step =  200 , loss_val =  1.4805135
# epochs =  28 , step =  300 , loss_val =  1.4615163
# epochs =  28 , step =  400 , loss_val =  1.4795898
# epochs =  28 , step =  500 , loss_val =  1.4802219
# epochs =  29 , step =  0 , loss_val =  1.4708431
# epochs =  29 , step =  100 , loss_val =  1.4611515
# epochs =  29 , step =  200 , loss_val =  1.4611515
# epochs =  29 , step =  300 , loss_val =  1.4817495
# epochs =  29 , step =  400 , loss_val =  1.4711502
# epochs =  29 , step =  500 , loss_val =  1.4611505
#
# elapsed time =  0:01:13.744485
#
# Accuracy =  0.9887

# %%
print(W5)
# Out:
# <tf.Variable 'Variable_6:0' shape=(2048, 10) dtype=float32_ref>
