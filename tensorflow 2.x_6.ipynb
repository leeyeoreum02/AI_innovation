# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.3.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape = ', x_train.shape, ', x_test.shape = ', x_test.shape)
print('t_train.shape = ', t_train.shape, ', t_test.shape = ', t_test.shape)
# Out:
# x_train.shape =  (60000, 28, 28) , x_test.shape =  (10000, 28, 28)
# t_train.shape =  (60000,) , t_test.shape =  (10000,)

# %%
model = Sequential()

model.add(Conv2D(input_shape=(28, 28, 1),
                 kernel_size=3, filters=32,
                 strides=(1, 1), activation='relu', use_bias=True, padding='SAME'))

model.add(MaxPool2D(pool_size=(2, 2), padding='SAME'))

model.add(Conv2D(input_shape=(28, 28, 1),
                 kernel_size=3, filters=64,
                 strides=(1, 1), activation='relu', use_bias=True, padding='SAME'))

model.add(MaxPool2D(pool_size=(2, 2), padding='SAME'))

model.add(Conv2D(input_shape=(28, 28, 1),
                 kernel_size=3, filters=128,
                 strides=(1, 1), activation='relu', use_bias=True, padding='SAME'))

model.add(MaxPool2D(pool_size=(2, 2), padding='SAME'))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(lr=1e-3),
               loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 7, 7, 128)         73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 113,162
# Trainable params: 113,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1, 28, 28, 1), t_train,
                 batch_size=50, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.1723 - accuracy: 0.9464 - val_loss: 0.0505 - val_accuracy: 0.9847
# Epoch 2/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0482 - accuracy: 0.9851 - val_loss: 0.0442 - val_accuracy: 0.9870
# Epoch 3/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0333 - accuracy: 0.9889 - val_loss: 0.0378 - val_accuracy: 0.9897
# Epoch 4/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0254 - accuracy: 0.9920 - val_loss: 0.0400 - val_accuracy: 0.9894
# Epoch 5/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0199 - accuracy: 0.9935 - val_loss: 0.0351 - val_accuracy: 0.9907
# Epoch 6/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0148 - accuracy: 0.9950 - val_loss: 0.0472 - val_accuracy: 0.9879
# Epoch 7/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.0297 - val_accuracy: 0.9925
# Epoch 8/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0102 - accuracy: 0.9964 - val_loss: 0.0309 - val_accuracy: 0.9926
# Epoch 9/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0333 - val_accuracy: 0.9916
# Epoch 10/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.0301 - val_accuracy: 0.9919
# Epoch 11/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0418 - val_accuracy: 0.9902
# Epoch 12/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.0480 - val_accuracy: 0.9902
# Epoch 13/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0509 - val_accuracy: 0.9897
# Epoch 14/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0471 - val_accuracy: 0.9900
# Epoch 15/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.0384 - val_accuracy: 0.9923
# Epoch 16/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0436 - val_accuracy: 0.9908
# Epoch 17/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0549 - val_accuracy: 0.9900
# Epoch 18/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0396 - val_accuracy: 0.9925
# Epoch 19/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0436 - val_accuracy: 0.9917
# Epoch 20/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0485 - val_accuracy: 0.9927
# Epoch 21/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0495 - val_accuracy: 0.9914
# Epoch 22/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0463 - val_accuracy: 0.9908
# Epoch 23/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0571 - val_accuracy: 0.9905
# Epoch 24/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0495 - val_accuracy: 0.9918
# Epoch 25/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0027 - accuracy: 0.9990 - val_loss: 0.0607 - val_accuracy: 0.9902
# Epoch 26/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0026 - accuracy: 0.9992 - val_loss: 0.0617 - val_accuracy: 0.9917
# Epoch 27/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 0.0589 - val_accuracy: 0.9912
# Epoch 28/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0555 - val_accuracy: 0.9924
# Epoch 29/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0668 - val_accuracy: 0.9908
# Epoch 30/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0566 - val_accuracy: 0.9911
# Epoch 31/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0579 - val_accuracy: 0.9918
# Epoch 32/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0524 - val_accuracy: 0.9923
# Epoch 33/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0635 - val_accuracy: 0.9917
# Epoch 34/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0617 - val_accuracy: 0.9918
# Epoch 35/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0591 - val_accuracy: 0.9923
# Epoch 36/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0636 - val_accuracy: 0.9916
# Epoch 37/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0527 - val_accuracy: 0.9936
# Epoch 38/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0018 - accuracy: 0.9993 - val_loss: 0.0648 - val_accuracy: 0.9924
# Epoch 39/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0639 - val_accuracy: 0.9920
# Epoch 40/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.0679 - val_accuracy: 0.9914
# Epoch 41/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0853 - val_accuracy: 0.9898
# Epoch 42/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0601 - val_accuracy: 0.9916
# Epoch 43/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.0747 - val_accuracy: 0.9897
# Epoch 44/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0655 - val_accuracy: 0.9923
# Epoch 45/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.0717 - val_accuracy: 0.9906
# Epoch 46/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0736 - val_accuracy: 0.9920
# Epoch 47/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0900 - val_accuracy: 0.9903
# Epoch 48/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0710 - val_accuracy: 0.9918
# Epoch 49/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0787 - val_accuracy: 0.9909
# Epoch 50/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0714 - val_accuracy: 0.9921

# %%
model.evaluate(x_test.reshape(-1, 28, 28, 1), t_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1087 - accuracy: 0.9835
# [0.1086890771985054, 0.9835000038146973]
