# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime


mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)

print()
print("train.num = ", mnist.train.num_examples)
print("test.num = ", mnist.test.num_examples)
print("validation_num = ", mnist.validation.num_examples)
# Out:
# WARNING:tensorflow:From <ipython-input-2-146c2c6b42db>:7: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
# train.num =  55000
# test.num =  10000
# validation_num =  5000

# %%
learning_rate = 1e-3
epochs = 30
batch_size = 100

# %%
X = tf.placeholder(tf.float32, [None, 784])

T = tf.placeholder(tf.float32, [None, 10])

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])

# %%
W2 = tf.Variable(tf.random_normal([5, 5, 1, 32], stddev=0.01))
b2 = tf.Variable(tf.random_normal([32]))

C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

Z2 = tf.nn.relu(C2 + b2)

A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
A2_flat = P2_flat = tf.reshape(A2, [-1, 14*14*32])

# %%
W3 = tf.Variable(tf.random_normal([14*14*32, 10], stddev=0.01))
b3 = tf.Variable(tf.random_normal([10]))

Z3 = logits = tf.matmul(A2_flat, W3) + b3

y = A3 = tf.nn.softmax(Z3)

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z3, labels=T))

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
predicted_val = tf.equal(tf.argmax(A3, 1), tf.argmax(T, 1))

accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

index = tf.argmax(A3, 1)
false_label = tf.argmax(T, 1)

false_prediction = (false_index, false_label, predicted_val)

# %%
with tf.Session() as sess:
  
  sess.run(tf.global_variables_initializer())

  start_time = datetime.now()

  for i in range(epochs):

    total_batch = int(mnist.train.num_examples / batch_size)

    for step in range(total_batch):

      batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)

      loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})

      if step % 100 == 0:
        print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)

  end_time = datetime.now()

  print("\nelapsed time = ", end_time - start_time)

  test_x_data = mnist.test.images
  test_t_data = mnist.test.labels

  accuracy_val = sess.run(accuracy, feed_dict={X: test_x_data, T: test_t_data})

  print("\nAccuracy = ", accuracy_val)

  index_label_prediction = sess.run(predicted_val, feed_dict={X: batch_x_data, T: batch_t_data})

  print(index_label_prediction)

  for
# Out:
# epochs =  0 , step =  0 , loss_val =  3.4160697
# epochs =  0 , step =  100 , loss_val =  0.97953534
# epochs =  0 , step =  200 , loss_val =  0.41411847
# epochs =  0 , step =  300 , loss_val =  0.4827637
# epochs =  0 , step =  400 , loss_val =  0.3521035
# epochs =  0 , step =  500 , loss_val =  0.34337494
# epochs =  1 , step =  0 , loss_val =  0.19062142
# epochs =  1 , step =  100 , loss_val =  0.26934287
# epochs =  1 , step =  200 , loss_val =  0.10921093
# epochs =  1 , step =  300 , loss_val =  0.32864526
# epochs =  1 , step =  400 , loss_val =  0.099338144
# epochs =  1 , step =  500 , loss_val =  0.14059825
# epochs =  2 , step =  0 , loss_val =  0.038138382
# epochs =  2 , step =  100 , loss_val =  0.068148345
# epochs =  2 , step =  200 , loss_val =  0.07602188
# epochs =  2 , step =  300 , loss_val =  0.10512413
# epochs =  2 , step =  400 , loss_val =  0.23490654
# epochs =  2 , step =  500 , loss_val =  0.13186325
# epochs =  3 , step =  0 , loss_val =  0.05626213
# epochs =  3 , step =  100 , loss_val =  0.06928922
# epochs =  3 , step =  200 , loss_val =  0.016260404
# epochs =  3 , step =  300 , loss_val =  0.095246226
# epochs =  3 , step =  400 , loss_val =  0.07666542
# epochs =  3 , step =  500 , loss_val =  0.1127068
# epochs =  4 , step =  0 , loss_val =  0.047787532
# epochs =  4 , step =  100 , loss_val =  0.15027241
# epochs =  4 , step =  200 , loss_val =  0.037104823
# epochs =  4 , step =  300 , loss_val =  0.065861486
# epochs =  4 , step =  400 , loss_val =  0.16697651
# epochs =  4 , step =  500 , loss_val =  0.05446316
# epochs =  5 , step =  0 , loss_val =  0.10643387
# epochs =  5 , step =  100 , loss_val =  0.06660036
# epochs =  5 , step =  200 , loss_val =  0.025061872
# epochs =  5 , step =  300 , loss_val =  0.038420793
# epochs =  5 , step =  400 , loss_val =  0.054711916
# epochs =  5 , step =  500 , loss_val =  0.021911003
# epochs =  6 , step =  0 , loss_val =  0.059363592
# epochs =  6 , step =  100 , loss_val =  0.069989346
# epochs =  6 , step =  200 , loss_val =  0.07025501
# epochs =  6 , step =  300 , loss_val =  0.028356228
# epochs =  6 , step =  400 , loss_val =  0.1007112
# epochs =  6 , step =  500 , loss_val =  0.02686175
# epochs =  7 , step =  0 , loss_val =  0.05414772
# epochs =  7 , step =  100 , loss_val =  0.028300185
# epochs =  7 , step =  200 , loss_val =  0.009542931
# epochs =  7 , step =  300 , loss_val =  0.035913497
# epochs =  7 , step =  400 , loss_val =  0.07888808
# epochs =  7 , step =  500 , loss_val =  0.09698605
# epochs =  8 , step =  0 , loss_val =  0.010804022
# epochs =  8 , step =  100 , loss_val =  0.047270805
# epochs =  8 , step =  200 , loss_val =  0.14433986
# epochs =  8 , step =  300 , loss_val =  0.043887407
# epochs =  8 , step =  400 , loss_val =  0.034608297
# epochs =  8 , step =  500 , loss_val =  0.04748087
# epochs =  9 , step =  0 , loss_val =  0.09596081
# epochs =  9 , step =  100 , loss_val =  0.008255452
# epochs =  9 , step =  200 , loss_val =  0.053649884
# epochs =  9 , step =  300 , loss_val =  0.005259248
# epochs =  9 , step =  400 , loss_val =  0.110318534
# epochs =  9 , step =  500 , loss_val =  0.08508539
# epochs =  10 , step =  0 , loss_val =  0.0056686015
# epochs =  10 , step =  100 , loss_val =  0.06296074
# epochs =  10 , step =  200 , loss_val =  0.07735128
# epochs =  10 , step =  300 , loss_val =  0.047829606
# epochs =  10 , step =  400 , loss_val =  0.013216279
# epochs =  10 , step =  500 , loss_val =  0.026314728
# epochs =  11 , step =  0 , loss_val =  0.034404058
# epochs =  11 , step =  100 , loss_val =  0.0063818097
# epochs =  11 , step =  200 , loss_val =  0.06103066
# epochs =  11 , step =  300 , loss_val =  0.090751074
# epochs =  11 , step =  400 , loss_val =  0.010873536
# epochs =  11 , step =  500 , loss_val =  0.13986461
# epochs =  12 , step =  0 , loss_val =  0.024279818
# epochs =  12 , step =  100 , loss_val =  0.027595665
# epochs =  12 , step =  200 , loss_val =  0.015061516
# epochs =  12 , step =  300 , loss_val =  0.016139904
# epochs =  12 , step =  400 , loss_val =  0.088011876
# epochs =  12 , step =  500 , loss_val =  0.057617698
# epochs =  13 , step =  0 , loss_val =  0.016340474
# epochs =  13 , step =  100 , loss_val =  0.018787375
# epochs =  13 , step =  200 , loss_val =  0.049367994
# epochs =  13 , step =  300 , loss_val =  0.014270041
# epochs =  13 , step =  400 , loss_val =  0.027390448
# epochs =  13 , step =  500 , loss_val =  0.042016614
# epochs =  14 , step =  0 , loss_val =  0.040362444
# epochs =  14 , step =  100 , loss_val =  0.009199486
# epochs =  14 , step =  200 , loss_val =  0.02790682
# epochs =  14 , step =  300 , loss_val =  0.029088264
# epochs =  14 , step =  400 , loss_val =  0.033050876
# epochs =  14 , step =  500 , loss_val =  0.044724688
# epochs =  15 , step =  0 , loss_val =  0.03999417
# epochs =  15 , step =  100 , loss_val =  0.040297963
# epochs =  15 , step =  200 , loss_val =  0.005674727
# epochs =  15 , step =  300 , loss_val =  0.035191312
# epochs =  15 , step =  400 , loss_val =  0.04341848
# epochs =  15 , step =  500 , loss_val =  0.047696862
# epochs =  16 , step =  0 , loss_val =  0.022971503
# epochs =  16 , step =  100 , loss_val =  0.059994284
# epochs =  16 , step =  200 , loss_val =  0.017591331
# epochs =  16 , step =  300 , loss_val =  0.065697744
# epochs =  16 , step =  400 , loss_val =  0.06718729
# epochs =  16 , step =  500 , loss_val =  0.011470164
# epochs =  17 , step =  0 , loss_val =  0.016713226
# epochs =  17 , step =  100 , loss_val =  0.044515394
# epochs =  17 , step =  200 , loss_val =  0.0028602409
# epochs =  17 , step =  300 , loss_val =  0.057485603
# epochs =  17 , step =  400 , loss_val =  0.011340596
# epochs =  17 , step =  500 , loss_val =  0.03134225
# epochs =  18 , step =  0 , loss_val =  0.020292314
# epochs =  18 , step =  100 , loss_val =  0.0050103487
# epochs =  18 , step =  200 , loss_val =  0.019722769
# epochs =  18 , step =  300 , loss_val =  0.013066847
# epochs =  18 , step =  400 , loss_val =  0.008077211
# epochs =  18 , step =  500 , loss_val =  0.031540092
# epochs =  19 , step =  0 , loss_val =  0.038158827
# epochs =  19 , step =  100 , loss_val =  0.023616726
# epochs =  19 , step =  200 , loss_val =  0.011194089
# epochs =  19 , step =  300 , loss_val =  0.019527089
# epochs =  19 , step =  400 , loss_val =  0.019726178
# epochs =  19 , step =  500 , loss_val =  0.0032915387
# epochs =  20 , step =  0 , loss_val =  0.0073707975
# epochs =  20 , step =  100 , loss_val =  0.0044835513
# epochs =  20 , step =  200 , loss_val =  0.007871103
# epochs =  20 , step =  300 , loss_val =  0.016102405
# epochs =  20 , step =  400 , loss_val =  0.021455543
# epochs =  20 , step =  500 , loss_val =  0.024534933
# epochs =  21 , step =  0 , loss_val =  0.007137315
# epochs =  21 , step =  100 , loss_val =  0.023316247
# epochs =  21 , step =  200 , loss_val =  0.014017153
# epochs =  21 , step =  300 , loss_val =  0.006147314
# epochs =  21 , step =  400 , loss_val =  0.028972853
# epochs =  21 , step =  500 , loss_val =  0.0023715326
# epochs =  22 , step =  0 , loss_val =  0.019491624
# epochs =  22 , step =  100 , loss_val =  0.0063579865
# epochs =  22 , step =  200 , loss_val =  0.0036967762
# epochs =  22 , step =  300 , loss_val =  0.011416014
# epochs =  22 , step =  400 , loss_val =  0.0146660805
# epochs =  22 , step =  500 , loss_val =  0.0075653074
# epochs =  23 , step =  0 , loss_val =  0.015080062
# epochs =  23 , step =  100 , loss_val =  0.020708222
# epochs =  23 , step =  200 , loss_val =  0.0044787307
# epochs =  23 , step =  300 , loss_val =  0.030243628
# epochs =  23 , step =  400 , loss_val =  0.0011386634
# epochs =  23 , step =  500 , loss_val =  0.002817208
# epochs =  24 , step =  0 , loss_val =  0.0046104444
# epochs =  24 , step =  100 , loss_val =  0.016645277
# epochs =  24 , step =  200 , loss_val =  0.0027289628
# epochs =  24 , step =  300 , loss_val =  0.010784689
# epochs =  24 , step =  400 , loss_val =  0.013518673
# epochs =  24 , step =  500 , loss_val =  0.004743932
# epochs =  25 , step =  0 , loss_val =  0.003330895
# epochs =  25 , step =  100 , loss_val =  0.026447123
# epochs =  25 , step =  200 , loss_val =  0.0018792561
# epochs =  25 , step =  300 , loss_val =  0.028459517
# epochs =  25 , step =  400 , loss_val =  0.004872836
# epochs =  25 , step =  500 , loss_val =  0.0054899226
# epochs =  26 , step =  0 , loss_val =  0.0022480756
# epochs =  26 , step =  100 , loss_val =  0.009464619
# epochs =  26 , step =  200 , loss_val =  0.008951133
# epochs =  26 , step =  300 , loss_val =  0.005637012
# epochs =  26 , step =  400 , loss_val =  0.01100582
# epochs =  26 , step =  500 , loss_val =  0.0015896456
# epochs =  27 , step =  0 , loss_val =  0.030474745
# epochs =  27 , step =  100 , loss_val =  0.001938975
# epochs =  27 , step =  200 , loss_val =  0.0035870727
# epochs =  27 , step =  300 , loss_val =  0.0150509
# epochs =  27 , step =  400 , loss_val =  0.010541885
# epochs =  27 , step =  500 , loss_val =  0.0025275303
# epochs =  28 , step =  0 , loss_val =  0.0052225543
# epochs =  28 , step =  100 , loss_val =  0.014949994
# epochs =  28 , step =  200 , loss_val =  0.0011877827
# epochs =  28 , step =  300 , loss_val =  0.0047229333
# epochs =  28 , step =  400 , loss_val =  0.0067252503
# epochs =  28 , step =  500 , loss_val =  0.004145709
# epochs =  29 , step =  0 , loss_val =  0.024261713
# epochs =  29 , step =  100 , loss_val =  0.0034080725
# epochs =  29 , step =  200 , loss_val =  0.015307082
# epochs =  29 , step =  300 , loss_val =  0.0014901934
# epochs =  29 , step =  400 , loss_val =  0.010179371
# epochs =  29 , step =  500 , loss_val =  0.0009617686
#
# elapsed time =  0:00:42.264525
#
# Accuracy =  0.9851
#
# index_label_prediction =  [ True  True  True ...  True  True  True]
