# %%
import tensorflow as tf

from tensorflow.keras.layers import Flatten, Dense, Conv2D, MaxPool2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist

import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.3.0

# %%
(x_train, t_train), (x_test, t_test) = mnist.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0

print('x_train.shape = ', x_train.shape, ', x_test.shape = ', x_test.shape)
print('t_train.shape = ', t_train.shape, ', t_test.shape = ', t_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# x_train.shape =  (60000, 28, 28) , x_test.shape =  (10000, 28, 28)
# t_train.shape =  (60000,) , t_test.shape =  (10000,)

# %%
model = Sequential()

model.add(Conv2D(input_shape=(28, 28, 1),
                 kernel_size=3, filters=32,
                 strides=(1, 1), activation='relu', use_bias=True, padding='SAME'))

model.add(MaxPool2D(pool_size=(2, 2), padding='SAME'))

model.add(Flatten())

model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(lr=1e-3),
               loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                62730
# =================================================================
# Total params: 63,050
# Trainable params: 63,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train.reshape(-1, 28, 28, 1), t_train,
                 batch_size=50, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.2875 - accuracy: 0.9178 - val_loss: 0.1231 - val_accuracy: 0.9682
# Epoch 2/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.1051 - accuracy: 0.9693 - val_loss: 0.0922 - val_accuracy: 0.9731
# Epoch 3/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0736 - accuracy: 0.9785 - val_loss: 0.0722 - val_accuracy: 0.9784
# Epoch 4/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0598 - accuracy: 0.9826 - val_loss: 0.0711 - val_accuracy: 0.9799
# Epoch 5/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0509 - accuracy: 0.9843 - val_loss: 0.0686 - val_accuracy: 0.9805
# Epoch 6/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0448 - accuracy: 0.9866 - val_loss: 0.0660 - val_accuracy: 0.9803
# Epoch 7/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0383 - accuracy: 0.9885 - val_loss: 0.0682 - val_accuracy: 0.9800
# Epoch 8/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0343 - accuracy: 0.9897 - val_loss: 0.0625 - val_accuracy: 0.9813
# Epoch 9/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0294 - accuracy: 0.9913 - val_loss: 0.0681 - val_accuracy: 0.9795
# Epoch 10/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0263 - accuracy: 0.9920 - val_loss: 0.0695 - val_accuracy: 0.9811
# Epoch 11/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0229 - accuracy: 0.9929 - val_loss: 0.0699 - val_accuracy: 0.9817
# Epoch 12/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.0199 - accuracy: 0.9943 - val_loss: 0.0714 - val_accuracy: 0.9810
# Epoch 13/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 0.0681 - val_accuracy: 0.9831
# Epoch 14/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.0153 - accuracy: 0.9956 - val_loss: 0.0764 - val_accuracy: 0.9803
# Epoch 15/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0140 - accuracy: 0.9959 - val_loss: 0.0733 - val_accuracy: 0.9818
# Epoch 16/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0118 - accuracy: 0.9969 - val_loss: 0.0743 - val_accuracy: 0.9808
# Epoch 17/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.0098 - accuracy: 0.9975 - val_loss: 0.0812 - val_accuracy: 0.9800
# Epoch 18/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.0846 - val_accuracy: 0.9812
# Epoch 19/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.0897 - val_accuracy: 0.9796
# Epoch 20/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0067 - accuracy: 0.9983 - val_loss: 0.0940 - val_accuracy: 0.9802
# Epoch 21/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0880 - val_accuracy: 0.9797
# Epoch 22/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0942 - val_accuracy: 0.9812
# Epoch 23/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.1043 - val_accuracy: 0.9776
# Epoch 24/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.0917 - val_accuracy: 0.9810
# Epoch 25/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0941 - val_accuracy: 0.9823
# Epoch 26/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.0991 - val_accuracy: 0.9797
# Epoch 27/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.1062 - val_accuracy: 0.9807
# Epoch 28/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.1008 - val_accuracy: 0.9798
# Epoch 29/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.1022 - val_accuracy: 0.9813
# Epoch 30/50
# 960/960 [==============================] - 3s 3ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.1030 - val_accuracy: 0.9812
# Epoch 31/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.1050 - val_accuracy: 0.9806
# Epoch 32/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.1061 - val_accuracy: 0.9806
# Epoch 33/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1106 - val_accuracy: 0.9795
# Epoch 34/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.0032 - accuracy: 0.9992 - val_loss: 0.1181 - val_accuracy: 0.9800
# Epoch 35/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.1137 - val_accuracy: 0.9796
# Epoch 36/50
# 960/960 [==============================] - 2s 3ms/step - loss: 9.3589e-04 - accuracy: 0.9999 - val_loss: 0.1150 - val_accuracy: 0.9805
# Epoch 37/50
# 960/960 [==============================] - 2s 3ms/step - loss: 5.6198e-04 - accuracy: 1.0000 - val_loss: 0.1139 - val_accuracy: 0.9810
# Epoch 38/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0039 - accuracy: 0.9988 - val_loss: 0.1282 - val_accuracy: 0.9793
# Epoch 39/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0012 - accuracy: 0.9998 - val_loss: 0.1175 - val_accuracy: 0.9810
# Epoch 40/50
# 960/960 [==============================] - 2s 3ms/step - loss: 2.5587e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9810
# Epoch 41/50
# 960/960 [==============================] - 3s 3ms/step - loss: 1.8314e-04 - accuracy: 1.0000 - val_loss: 0.1193 - val_accuracy: 0.9813
# Epoch 42/50
# 960/960 [==============================] - 3s 3ms/step - loss: 1.8413e-04 - accuracy: 1.0000 - val_loss: 0.1324 - val_accuracy: 0.9797
# Epoch 43/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.1236 - val_accuracy: 0.9803
# Epoch 44/50
# 960/960 [==============================] - 2s 2ms/step - loss: 5.2016e-04 - accuracy: 1.0000 - val_loss: 0.1216 - val_accuracy: 0.9819
# Epoch 45/50
# 960/960 [==============================] - 2s 2ms/step - loss: 1.9091e-04 - accuracy: 1.0000 - val_loss: 0.1210 - val_accuracy: 0.9822
# Epoch 46/50
# 960/960 [==============================] - 2s 2ms/step - loss: 1.3809e-04 - accuracy: 1.0000 - val_loss: 0.1226 - val_accuracy: 0.9822
# Epoch 47/50
# 960/960 [==============================] - 2s 3ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.1486 - val_accuracy: 0.9790
# Epoch 48/50
# 960/960 [==============================] - 2s 2ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1242 - val_accuracy: 0.9807
# Epoch 49/50
# 960/960 [==============================] - 2s 2ms/step - loss: 4.6149e-04 - accuracy: 1.0000 - val_loss: 0.1224 - val_accuracy: 0.9815
# Epoch 50/50
# 960/960 [==============================] - 2s 2ms/step - loss: 1.4578e-04 - accuracy: 1.0000 - val_loss: 0.1227 - val_accuracy: 0.9818

# %%
model.evaluate(x_test.reshape(-1, 28, 28, 1), t_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1087 - accuracy: 0.9835
# [0.1086890771985054, 0.9835000038146973]
