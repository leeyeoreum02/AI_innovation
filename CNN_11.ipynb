# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime


mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)

print()
print("train.num = ", mnist.train.num_examples)
print("test.num = ", mnist.test.num_examples)
print("validation_num = ", mnist.validation.num_examples)
# Out:
# WARNING:tensorflow:From <ipython-input-2-146c2c6b42db>:7: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
# train.num =  55000
# test.num =  10000
# validation_num =  5000

# %%
learning_rate = 1e-3
epochs = 30
batch_size = 100

# %%
X = tf.placeholder(tf.float32, [None, 784])

T = tf.placeholder(tf.float32, [None, 10])

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])

# %%
W2 = tf.Variable(tf.random_normal([3, 3, 1, 32], stddev=0.01))
b2 = tf.Variable(tf.random_normal([32]))

C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

Z2 = tf.nn.relu(C2 + b2)

A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
W3 = tf.Variable(tf.random_normal([3, 3, 1, 64], stddev=0.01))
b3 = tf.Variable(tf.random_normal([64]))

C3 = tf.nn.conv2d(A2, W3, strides=[1, 1, 1, 1], padding='SAME')

Z3 = tf.nn.relu(C3 + b3)

A3 = P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
W4 = tf.Variable(tf.random_normal([3, 3, 1, 128], stddev=0.01))
b4 = tf.Variable(tf.random_normal([128]))

C4 = tf.nn.conv2d(A3, W4, strides=[1, 1, 1, 1], padding='SAME')

A4 = tf.nn.relu(C4 + b4)

# %%
A4_flat = P4_flat = tf.reshape(A4, [-1, 7*7*128])

# %%
W5 = tf.Variable(tf.random_normal([7*7*128, 10]))
b5 = tf.Variable(tf.random_normal([10]))

Z5 = logits = tf.matmul(A4_flat, W5) + b5
y = A5 = tf.nn.softmax(Z5)

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z5, labels=T))

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
predicted_val = tf.equal(tf.argmax(A5, 1), tf.argmax(T, 1))

accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

predicted_list = tf.argmax(A5, 1)
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# %%
index_label_prediction_list = []

with tf.Session() as sess:
  
  sess.run(tf.global_variables_initializer())

  start_time = datetime.now()

  for i in range(epochs):

    total_batch = int(mnist.train.num_examples / batch_size)

    for step in range(total_batch):

      batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)

      loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})

      if step % 100 == 0:
        print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)

  end_time = datetime.now()

  print("\nelapsed time = ", end_time - start_time)

  test_x_data = mnist.test.images
  test_t_data = mnist.test.labels

  accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})

  print("\nAccuracy = ", accuracy_val)
  print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
  print("index_label.shape = ", index_label.shape)
    
  index_label_list = list(index_label)
  print("length of index_label_list = ", len(index_label_list))
  print("false label count = ", index_label_list.count([0]))
        
  temp_list = [] 
    
  for index in range(len(index_label)):
        
      if index_label[index] == 0:
            
          temp_list.append(index)
          temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
          temp_list.append(predicted_list_val[index])
            
          index_label_prediction_list.append(temp_list)
            
          temp_list = []
            
  print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  61.369827
# epochs =  0 , step =  100 , loss_val =  2.4204402
# epochs =  0 , step =  200 , loss_val =  2.321956
# epochs =  0 , step =  300 , loss_val =  2.1826425
# epochs =  0 , step =  400 , loss_val =  1.8324344
# epochs =  0 , step =  500 , loss_val =  1.5375495
# epochs =  1 , step =  0 , loss_val =  1.243689
# epochs =  1 , step =  100 , loss_val =  1.1117831
# epochs =  1 , step =  200 , loss_val =  1.088642
# epochs =  1 , step =  300 , loss_val =  0.96901125
# epochs =  1 , step =  400 , loss_val =  0.77686965
# epochs =  1 , step =  500 , loss_val =  0.75883585
# epochs =  2 , step =  0 , loss_val =  0.8260511
# epochs =  2 , step =  100 , loss_val =  0.7647062
# epochs =  2 , step =  200 , loss_val =  0.7206023
# epochs =  2 , step =  300 , loss_val =  0.7032305
# epochs =  2 , step =  400 , loss_val =  0.50209147
# epochs =  2 , step =  500 , loss_val =  0.5055973
# epochs =  3 , step =  0 , loss_val =  0.4368237
# epochs =  3 , step =  100 , loss_val =  0.5318434
# epochs =  3 , step =  200 , loss_val =  0.5133439
# epochs =  3 , step =  300 , loss_val =  0.41180187
# epochs =  3 , step =  400 , loss_val =  0.41773704
# epochs =  3 , step =  500 , loss_val =  0.5442446
# epochs =  4 , step =  0 , loss_val =  0.44902962
# epochs =  4 , step =  100 , loss_val =  0.27782738
# epochs =  4 , step =  200 , loss_val =  0.3473866
# epochs =  4 , step =  300 , loss_val =  0.48365957
# epochs =  4 , step =  400 , loss_val =  0.38052413
# epochs =  4 , step =  500 , loss_val =  0.56116784
# epochs =  5 , step =  0 , loss_val =  0.5775204
# epochs =  5 , step =  100 , loss_val =  0.2293531
# epochs =  5 , step =  200 , loss_val =  0.3542079
# epochs =  5 , step =  300 , loss_val =  0.2811181
# epochs =  5 , step =  400 , loss_val =  0.34672153
# epochs =  5 , step =  500 , loss_val =  0.26982272
# epochs =  6 , step =  0 , loss_val =  0.6659145
# epochs =  6 , step =  100 , loss_val =  0.4248338
# epochs =  6 , step =  200 , loss_val =  0.34466088
# epochs =  6 , step =  300 , loss_val =  0.3457165
# epochs =  6 , step =  400 , loss_val =  0.3900026
# epochs =  6 , step =  500 , loss_val =  0.29386148
# epochs =  7 , step =  0 , loss_val =  0.3233654
# epochs =  7 , step =  100 , loss_val =  0.41785026
# epochs =  7 , step =  200 , loss_val =  0.14468473
# epochs =  7 , step =  300 , loss_val =  0.3034413
# epochs =  7 , step =  400 , loss_val =  0.27032462
# epochs =  7 , step =  500 , loss_val =  0.22409907
# epochs =  8 , step =  0 , loss_val =  0.27976823
# epochs =  8 , step =  100 , loss_val =  0.13114426
# epochs =  8 , step =  200 , loss_val =  0.31624344
# epochs =  8 , step =  300 , loss_val =  0.14845183
# epochs =  8 , step =  400 , loss_val =  0.1534515
# epochs =  8 , step =  500 , loss_val =  0.24471734
# epochs =  9 , step =  0 , loss_val =  0.2904971
# epochs =  9 , step =  100 , loss_val =  0.30982614
# epochs =  9 , step =  200 , loss_val =  0.29702416
# epochs =  9 , step =  300 , loss_val =  0.21994732
# epochs =  9 , step =  400 , loss_val =  0.25591224
# epochs =  9 , step =  500 , loss_val =  0.30967453
# epochs =  10 , step =  0 , loss_val =  0.2869376
# epochs =  10 , step =  100 , loss_val =  0.3026468
# epochs =  10 , step =  200 , loss_val =  0.18113026
# epochs =  10 , step =  300 , loss_val =  0.08078997
# epochs =  10 , step =  400 , loss_val =  0.31278878
# epochs =  10 , step =  500 , loss_val =  0.110305145
# epochs =  11 , step =  0 , loss_val =  0.19147214
# epochs =  11 , step =  100 , loss_val =  0.17068936
# epochs =  11 , step =  200 , loss_val =  0.37814906
# epochs =  11 , step =  300 , loss_val =  0.18875915
# epochs =  11 , step =  400 , loss_val =  0.21420123
# epochs =  11 , step =  500 , loss_val =  0.11762227
# epochs =  12 , step =  0 , loss_val =  0.2805435
# epochs =  12 , step =  100 , loss_val =  0.28416657
# epochs =  12 , step =  200 , loss_val =  0.1452114
# epochs =  12 , step =  300 , loss_val =  0.3064545
# epochs =  12 , step =  400 , loss_val =  0.17810656
# epochs =  12 , step =  500 , loss_val =  0.06163806
# epochs =  13 , step =  0 , loss_val =  0.18177277
# epochs =  13 , step =  100 , loss_val =  0.37899545
# epochs =  13 , step =  200 , loss_val =  0.14740397
# epochs =  13 , step =  300 , loss_val =  0.2583075
# epochs =  13 , step =  400 , loss_val =  0.18899052
# epochs =  13 , step =  500 , loss_val =  0.11898591
# epochs =  14 , step =  0 , loss_val =  0.34722736
# epochs =  14 , step =  100 , loss_val =  0.25165936
# epochs =  14 , step =  200 , loss_val =  0.32033813
# epochs =  14 , step =  300 , loss_val =  0.25348788
# epochs =  14 , step =  400 , loss_val =  0.17049083
# epochs =  14 , step =  500 , loss_val =  0.14718276
# epochs =  15 , step =  0 , loss_val =  0.03648727
# epochs =  15 , step =  100 , loss_val =  0.112664804
# epochs =  15 , step =  200 , loss_val =  0.093658164
# epochs =  15 , step =  300 , loss_val =  0.1662509
# epochs =  15 , step =  400 , loss_val =  0.13662541
# epochs =  15 , step =  500 , loss_val =  0.22166418
# epochs =  16 , step =  0 , loss_val =  0.18907358
# epochs =  16 , step =  100 , loss_val =  0.079949625
# epochs =  16 , step =  200 , loss_val =  0.22578435
# epochs =  16 , step =  300 , loss_val =  0.18496944
# epochs =  16 , step =  400 , loss_val =  0.15957908
# epochs =  16 , step =  500 , loss_val =  0.17323758
# epochs =  17 , step =  0 , loss_val =  0.22736391
# epochs =  17 , step =  100 , loss_val =  0.13704166
# epochs =  17 , step =  200 , loss_val =  0.16755661
# epochs =  17 , step =  300 , loss_val =  0.26412797
# epochs =  17 , step =  400 , loss_val =  0.108592965
# epochs =  17 , step =  500 , loss_val =  0.120995484
# epochs =  18 , step =  0 , loss_val =  0.33781052
# epochs =  18 , step =  100 , loss_val =  0.09923378
# epochs =  18 , step =  200 , loss_val =  0.060963005
# epochs =  18 , step =  300 , loss_val =  0.07904229
# epochs =  18 , step =  400 , loss_val =  0.21197093
# epochs =  18 , step =  500 , loss_val =  0.16783693
# epochs =  19 , step =  0 , loss_val =  0.03947361
# epochs =  19 , step =  100 , loss_val =  0.12783876
# epochs =  19 , step =  200 , loss_val =  0.31937075
# epochs =  19 , step =  300 , loss_val =  0.15900187
# epochs =  19 , step =  400 , loss_val =  0.11996705
# epochs =  19 , step =  500 , loss_val =  0.048207898
# epochs =  20 , step =  0 , loss_val =  0.22426753
# epochs =  20 , step =  100 , loss_val =  0.10176457
# epochs =  20 , step =  200 , loss_val =  0.17060128
# epochs =  20 , step =  300 , loss_val =  0.16374432
# epochs =  20 , step =  400 , loss_val =  0.14120238
# epochs =  20 , step =  500 , loss_val =  0.08091763
# epochs =  21 , step =  0 , loss_val =  0.07935346
# epochs =  21 , step =  100 , loss_val =  0.1656642
# epochs =  21 , step =  200 , loss_val =  0.13485354
# epochs =  21 , step =  300 , loss_val =  0.04881992
# epochs =  21 , step =  400 , loss_val =  0.13748512
# epochs =  21 , step =  500 , loss_val =  0.22548676
# epochs =  22 , step =  0 , loss_val =  0.07814674
# epochs =  22 , step =  100 , loss_val =  0.25133294
# epochs =  22 , step =  200 , loss_val =  0.120812014
# epochs =  22 , step =  300 , loss_val =  0.07335379
# epochs =  22 , step =  400 , loss_val =  0.11589371
# epochs =  22 , step =  500 , loss_val =  0.09207303
# epochs =  23 , step =  0 , loss_val =  0.09800969
# epochs =  23 , step =  100 , loss_val =  0.06229392
# epochs =  23 , step =  200 , loss_val =  0.09498982
# epochs =  23 , step =  300 , loss_val =  0.11494255
# epochs =  23 , step =  400 , loss_val =  0.15672472
# epochs =  23 , step =  500 , loss_val =  0.09912335
# epochs =  24 , step =  0 , loss_val =  0.11636789
# epochs =  24 , step =  100 , loss_val =  0.08769746
# epochs =  24 , step =  200 , loss_val =  0.03889974
# epochs =  24 , step =  300 , loss_val =  0.121109135
# epochs =  24 , step =  400 , loss_val =  0.02309605
# epochs =  24 , step =  500 , loss_val =  0.14459625
# epochs =  25 , step =  0 , loss_val =  0.19879313
# epochs =  25 , step =  100 , loss_val =  0.089325875
# epochs =  25 , step =  200 , loss_val =  0.14346962
# epochs =  25 , step =  300 , loss_val =  0.020228691
# epochs =  25 , step =  400 , loss_val =  0.1789215
# epochs =  25 , step =  500 , loss_val =  0.23917314
# epochs =  26 , step =  0 , loss_val =  0.055093765
# epochs =  26 , step =  100 , loss_val =  0.17506884
# epochs =  26 , step =  200 , loss_val =  0.08647585
# epochs =  26 , step =  300 , loss_val =  0.23001322
# epochs =  26 , step =  400 , loss_val =  0.0644754
# epochs =  26 , step =  500 , loss_val =  0.07321627
# epochs =  27 , step =  0 , loss_val =  0.038783558
# epochs =  27 , step =  100 , loss_val =  0.066487335
# epochs =  27 , step =  200 , loss_val =  0.16461693
# epochs =  27 , step =  300 , loss_val =  0.093505725
# epochs =  27 , step =  400 , loss_val =  0.15004838
# epochs =  27 , step =  500 , loss_val =  0.048426267
# epochs =  28 , step =  0 , loss_val =  0.2276587
# epochs =  28 , step =  100 , loss_val =  0.19946235
# epochs =  28 , step =  200 , loss_val =  0.08927336
# epochs =  28 , step =  300 , loss_val =  0.1212804
# epochs =  28 , step =  400 , loss_val =  0.18791023
# epochs =  28 , step =  500 , loss_val =  0.25617692
# epochs =  29 , step =  0 , loss_val =  0.08371598
# epochs =  29 , step =  100 , loss_val =  0.051462494
# epochs =  29 , step =  200 , loss_val =  0.11976896
# epochs =  29 , step =  300 , loss_val =  0.08092704
# epochs =  29 , step =  400 , loss_val =  0.21414736
# epochs =  29 , step =  500 , loss_val =  0.18538252
#
# elapsed time =  0:01:00.329167
#
# Accuracy =  0.9663
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  337
#
# length of index_label_false_list 337

# %%
print(index_label_prediction_list)
# Out:
# [[33, 4, 6], [92, 9, 4], [149, 2, 3], [184, 8, 2], [193, 9, 8], [211, 5, 3], [247, 4, 6], [259, 6, 0], [290, 8, 4], [300, 4, 6], [318, 2, 3], [320, 9, 7], [321, 2, 7], [324, 0, 5], [359, 9, 4], [445, 6, 0], [448, 9, 8], [479, 9, 3], [543, 8, 2], [582, 8, 2], [591, 8, 3], [613, 2, 7], [655, 8, 2], [659, 2, 1], [684, 7, 3], [717, 0, 5], [720, 5, 8], [726, 7, 5], [800, 8, 3], [839, 8, 3], [882, 9, 7], [924, 2, 3], [926, 2, 8], [938, 3, 5], [947, 8, 9], [950, 7, 2], [956, 1, 2], [965, 6, 0], [1014, 6, 5], [1039, 7, 1], [1068, 8, 4], [1101, 8, 3], [1107, 9, 3], [1112, 4, 6], [1156, 7, 8], [1181, 6, 1], [1182, 6, 5], [1226, 7, 3], [1232, 9, 4], [1242, 4, 9], [1247, 9, 5], [1251, 2, 3], [1256, 2, 3], [1260, 7, 1], [1299, 5, 7], [1319, 8, 0], [1326, 7, 2], [1364, 8, 2], [1393, 5, 3], [1414, 9, 4], [1415, 8, 6], [1433, 8, 1], [1500, 7, 1], [1522, 7, 1], [1527, 1, 5], [1530, 8, 7], [1549, 4, 6], [1551, 2, 3], [1553, 9, 3], [1559, 9, 3], [1569, 6, 3], [1570, 0, 6], [1581, 7, 9], [1609, 2, 0], [1634, 4, 8], [1676, 6, 5], [1681, 3, 7], [1709, 9, 3], [1717, 8, 0], [1754, 7, 2], [1759, 8, 5], [1782, 8, 7], [1790, 2, 7], [1823, 8, 6], [1850, 8, 7], [1871, 2, 3], [1878, 8, 3], [1901, 9, 4], [1940, 5, 0], [1955, 8, 2], [1968, 8, 9], [1982, 6, 5], [2009, 9, 7], [2016, 7, 2], [2035, 5, 3], [2044, 2, 7], [2053, 4, 9], [2068, 9, 4], [2070, 7, 9], [2098, 2, 0], [2109, 3, 7], [2118, 6, 0], [2129, 9, 8], [2130, 4, 9], [2135, 6, 1], [2179, 8, 3], [2182, 1, 3], [2185, 0, 8], [2186, 2, 0], [2224, 5, 6], [2242, 2, 3], [2266, 1, 6], [2280, 3, 5], [2293, 9, 2], [2299, 2, 7], [2309, 8, 5], [2325, 7, 3], [2326, 0, 5], [2329, 0, 2], [2378, 0, 5], [2387, 9, 1], [2393, 8, 3], [2406, 9, 2], [2414, 9, 4], [2417, 0, 6], [2455, 0, 6], [2488, 2, 4], [2525, 5, 3], [2532, 6, 1], [2578, 7, 2], [2607, 7, 3], [2618, 3, 5], [2648, 9, 5], [2654, 6, 1], [2713, 0, 8], [2735, 9, 7], [2760, 9, 4], [2780, 2, 3], [2836, 4, 1], [2863, 9, 4], [2896, 8, 0], [2911, 8, 2], [2939, 9, 5], [2952, 3, 5], [2961, 7, 3], [2979, 9, 0], [2995, 6, 5], [3005, 9, 5], [3060, 9, 7], [3073, 1, 2], [3109, 7, 1], [3114, 4, 2], [3130, 6, 0], [3136, 7, 8], [3206, 8, 3], [3240, 9, 3], [3288, 4, 9], [3329, 7, 3], [3369, 9, 1], [3384, 2, 6], [3392, 9, 5], [3422, 6, 0], [3503, 9, 1], [3520, 6, 4], [3567, 8, 5], [3597, 9, 3], [3599, 2, 1], [3604, 7, 0], [3626, 8, 3], [3629, 8, 5], [3656, 7, 3], [3662, 8, 0], [3723, 9, 6], [3767, 7, 3], [3780, 4, 6], [3794, 8, 3], [3811, 2, 0], [3838, 7, 8], [3848, 7, 3], [3862, 2, 3], [3869, 9, 4], [3871, 8, 3], [3902, 5, 3], [3906, 1, 3], [3926, 9, 3], [3941, 4, 6], [3967, 9, 7], [3985, 9, 4], [3986, 2, 3], [4044, 3, 5], [4075, 8, 0], [4078, 9, 3], [4123, 8, 3], [4163, 9, 7], [4176, 2, 7], [4199, 7, 9], [4201, 1, 4], [4205, 2, 8], [4207, 8, 2], [4224, 9, 7], [4238, 7, 3], [4248, 2, 8], [4265, 4, 7], [4289, 2, 7], [4294, 9, 7], [4306, 3, 7], [4344, 9, 5], [4355, 5, 3], [4359, 5, 7], [4369, 9, 4], [4380, 8, 5], [4399, 8, 6], [4433, 7, 2], [4443, 3, 1], [4497, 8, 7], [4498, 7, 3], [4500, 9, 1], [4536, 6, 5], [4575, 4, 2], [4601, 8, 4], [4640, 8, 3], [4724, 8, 0], [4731, 8, 3], [4735, 9, 4], [4740, 3, 5], [4743, 8, 6], [4761, 9, 8], [4807, 8, 3], [4823, 9, 6], [4837, 7, 2], [4874, 9, 5], [4876, 2, 0], [4879, 8, 6], [4886, 7, 1], [4956, 8, 4], [4978, 8, 7], [4990, 3, 2], [5065, 8, 1], [5159, 4, 9], [5210, 9, 3], [5246, 7, 2], [5268, 9, 8], [5331, 1, 6], [5457, 1, 2], [5600, 7, 9], [5642, 1, 6], [5749, 8, 5], [5888, 4, 0], [5955, 3, 8], [6026, 7, 1], [6071, 9, 3], [6081, 9, 5], [6091, 9, 5], [6093, 2, 3], [6112, 9, 5], [6124, 9, 5], [6126, 9, 5], [6157, 9, 5], [6166, 9, 3], [6172, 9, 5], [6495, 8, 9], [6505, 9, 0], [6558, 6, 2], [6569, 3, 2], [6576, 7, 1], [6578, 8, 5], [6597, 0, 7], [6608, 9, 3], [6627, 9, 5], [6642, 9, 5], [6651, 0, 2], [6725, 8, 5], [6740, 9, 0], [6744, 2, 8], [6765, 8, 5], [6783, 1, 6], [6796, 2, 7], [6895, 9, 7], [7035, 8, 3], [7121, 8, 9], [7135, 2, 7], [7216, 0, 3], [7432, 7, 2], [7434, 4, 8], [7580, 9, 4], [7813, 9, 8], [7899, 1, 8], [7921, 8, 5], [7931,  ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
false_data_index = np.random.randint(len(index_label_prediction_list))

print('len of index_label_prediction_list => ', len(index_label_prediction_list), ', false_data_index => ', false_data_index)

mnist_index = index_label_prediction_list[false_data_index][0]
label = index_label_prediction_list[false_data_index][1]
prediction = index_label_prediction_list[false_data_index][2]

title_str = 'index = ' + str(mnist_index) + ' , label = ' + str(label) + ' , prediction = ' + str(prediction)

img = test_x_data[mnist_index].reshape(28,28)


plt.title(title_str)
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# len of index_label_prediction_list =>  337 , false_data_index =>  280
