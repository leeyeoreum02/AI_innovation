# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime


mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)

print()
print("train.num = ", mnist.train.num_examples)
print("test.num = ", mnist.test.num_examples)
print("validation_num = ", mnist.validation.num_examples)
# Out:
# WARNING:tensorflow:From <ipython-input-2-146c2c6b42db>:7: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
# train.num =  55000
# test.num =  10000
# validation_num =  5000

# %%
learning_rate = 1e-3
epochs = 30
batch_size = 100

# %%
X = tf.placeholder(tf.float32, [None, 784])

T = tf.placeholder(tf.float32, [None, 10])

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])

# %%
W2 = tf.Variable(tf.random_normal([3, 3, 1, 64], stddev=0.01))
b2 = tf.Variable(tf.random_normal([64]))

C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

Z2 = tf.nn.relu(C2 + b2)

A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
A2_flat = P2_flat = tf.reshape(A2, [-1, 14*14*64])

# %%
W3 = tf.Variable(tf.random_normal([14*14*64, 10], stddev=0.01))
b3 = tf.Variable(tf.random_normal([10]))

Z3 = logits = tf.matmul(A2_flat, W3) + b3

y = A3 = tf.nn.softmax(Z3)

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z3, labels=T))

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
predicted_val = tf.equal(tf.argmax(A3, 1), tf.argmax(T, 1))

accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# %%
with tf.Session() as sess:
  
  sess.run(tf.global_variables_initializer())

  start_time = datetime.now()

  for i in range(epochs):

    total_batch = int(mnist.train.num_examples / batch_size)

    for step in range(total_batch):

      batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)

      loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})

      if step % 100 == 0:
        print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)

  end_time = datetime.now()

  print("\nelapsed time = ", end_time - start_time)

  test_x_data = mnist.test.images
  test_t_data = mnist.test.labels

  accuracy_val = sess.run(accuracy, feed_dict={X: test_x_data, T: test_t_data})

  print("\nAccuracy = ", accuracy_val)
# Out:
# epochs =  0 , step =  0 , loss_val =  3.0174322
# epochs =  0 , step =  100 , loss_val =  2.0381587
# epochs =  0 , step =  200 , loss_val =  0.71926
# epochs =  0 , step =  300 , loss_val =  0.6329477
# epochs =  0 , step =  400 , loss_val =  0.6318839
# epochs =  0 , step =  500 , loss_val =  0.54540765
# epochs =  1 , step =  0 , loss_val =  0.40120462
# epochs =  1 , step =  100 , loss_val =  0.6019118
# epochs =  1 , step =  200 , loss_val =  0.5789195
# epochs =  1 , step =  300 , loss_val =  0.30039638
# epochs =  1 , step =  400 , loss_val =  0.34615967
# epochs =  1 , step =  500 , loss_val =  0.49726722
# epochs =  2 , step =  0 , loss_val =  0.24285963
# epochs =  2 , step =  100 , loss_val =  0.17209606
# epochs =  2 , step =  200 , loss_val =  0.43146488
# epochs =  2 , step =  300 , loss_val =  0.31631348
# epochs =  2 , step =  400 , loss_val =  0.331954
# epochs =  2 , step =  500 , loss_val =  0.53976786
# epochs =  3 , step =  0 , loss_val =  0.38122398
# epochs =  3 , step =  100 , loss_val =  0.20136511
# epochs =  3 , step =  200 , loss_val =  0.2770224
# epochs =  3 , step =  300 , loss_val =  0.2178627
# epochs =  3 , step =  400 , loss_val =  0.37927637
# epochs =  3 , step =  500 , loss_val =  0.30904254
# epochs =  4 , step =  0 , loss_val =  0.13293558
# epochs =  4 , step =  100 , loss_val =  0.24221845
# epochs =  4 , step =  200 , loss_val =  0.38411552
# epochs =  4 , step =  300 , loss_val =  0.17184366
# epochs =  4 , step =  400 , loss_val =  0.20244169
# epochs =  4 , step =  500 , loss_val =  0.29125443
# epochs =  5 , step =  0 , loss_val =  0.253108
# epochs =  5 , step =  100 , loss_val =  0.25545302
# epochs =  5 , step =  200 , loss_val =  0.15165529
# epochs =  5 , step =  300 , loss_val =  0.09801997
# epochs =  5 , step =  400 , loss_val =  0.21537706
# epochs =  5 , step =  500 , loss_val =  0.21842018
# epochs =  6 , step =  0 , loss_val =  0.32189095
# epochs =  6 , step =  100 , loss_val =  0.21976368
# epochs =  6 , step =  200 , loss_val =  0.26538894
# epochs =  6 , step =  300 , loss_val =  0.29356247
# epochs =  6 , step =  400 , loss_val =  0.19465724
# epochs =  6 , step =  500 , loss_val =  0.05210165
# epochs =  7 , step =  0 , loss_val =  0.06826267
# epochs =  7 , step =  100 , loss_val =  0.10832758
# epochs =  7 , step =  200 , loss_val =  0.068879604
# epochs =  7 , step =  300 , loss_val =  0.12585896
# epochs =  7 , step =  400 , loss_val =  0.19963637
# epochs =  7 , step =  500 , loss_val =  0.219351
# epochs =  8 , step =  0 , loss_val =  0.20335016
# epochs =  8 , step =  100 , loss_val =  0.22486319
# epochs =  8 , step =  200 , loss_val =  0.15570775
# epochs =  8 , step =  300 , loss_val =  0.0873661
# epochs =  8 , step =  400 , loss_val =  0.059021503
# epochs =  8 , step =  500 , loss_val =  0.14306545
# epochs =  9 , step =  0 , loss_val =  0.08423261
# epochs =  9 , step =  100 , loss_val =  0.065001294
# epochs =  9 , step =  200 , loss_val =  0.11984028
# epochs =  9 , step =  300 , loss_val =  0.1493928
# epochs =  9 , step =  400 , loss_val =  0.06904334
# epochs =  9 , step =  500 , loss_val =  0.017272329
# epochs =  10 , step =  0 , loss_val =  0.13152254
# epochs =  10 , step =  100 , loss_val =  0.035277788
# epochs =  10 , step =  200 , loss_val =  0.13654688
# epochs =  10 , step =  300 , loss_val =  0.047083717
# epochs =  10 , step =  400 , loss_val =  0.2539918
# epochs =  10 , step =  500 , loss_val =  0.033857487
# epochs =  11 , step =  0 , loss_val =  0.11609618
# epochs =  11 , step =  100 , loss_val =  0.13346887
# epochs =  11 , step =  200 , loss_val =  0.02859429
# epochs =  11 , step =  300 , loss_val =  0.13205507
# epochs =  11 , step =  400 , loss_val =  0.03336163
# epochs =  11 , step =  500 , loss_val =  0.11495755
# epochs =  12 , step =  0 , loss_val =  0.046334337
# epochs =  12 , step =  100 , loss_val =  0.0261853
# epochs =  12 , step =  200 , loss_val =  0.14472274
# epochs =  12 , step =  300 , loss_val =  0.022824926
# epochs =  12 , step =  400 , loss_val =  0.08399826
# epochs =  12 , step =  500 , loss_val =  0.058343053
# epochs =  13 , step =  0 , loss_val =  0.072753176
# epochs =  13 , step =  100 , loss_val =  0.034891855
# epochs =  13 , step =  200 , loss_val =  0.031812824
# epochs =  13 , step =  300 , loss_val =  0.116660625
# epochs =  13 , step =  400 , loss_val =  0.09585289
# epochs =  13 , step =  500 , loss_val =  0.04380514
# epochs =  14 , step =  0 , loss_val =  0.032721177
# epochs =  14 , step =  100 , loss_val =  0.06478054
# epochs =  14 , step =  200 , loss_val =  0.10727201
# epochs =  14 , step =  300 , loss_val =  0.05966268
# epochs =  14 , step =  400 , loss_val =  0.016939795
# epochs =  14 , step =  500 , loss_val =  0.07490097
# epochs =  15 , step =  0 , loss_val =  0.1571692
# epochs =  15 , step =  100 , loss_val =  0.048188947
# epochs =  15 , step =  200 , loss_val =  0.02950994
# epochs =  15 , step =  300 , loss_val =  0.040665478
# epochs =  15 , step =  400 , loss_val =  0.04225504
# epochs =  15 , step =  500 , loss_val =  0.05785142
# epochs =  16 , step =  0 , loss_val =  0.031657036
# epochs =  16 , step =  100 , loss_val =  0.111992426
# epochs =  16 , step =  200 , loss_val =  0.1257808
# epochs =  16 , step =  300 , loss_val =  0.025539074
# epochs =  16 , step =  400 , loss_val =  0.028773794
# epochs =  16 , step =  500 , loss_val =  0.11892915
# epochs =  17 , step =  0 , loss_val =  0.019958725
# epochs =  17 , step =  100 , loss_val =  0.0476716
# epochs =  17 , step =  200 , loss_val =  0.01639592
# epochs =  17 , step =  300 , loss_val =  0.13728198
# epochs =  17 , step =  400 , loss_val =  0.08522499
# epochs =  17 , step =  500 , loss_val =  0.03468117
# epochs =  18 , step =  0 , loss_val =  0.028235791
# epochs =  18 , step =  100 , loss_val =  0.03559132
# epochs =  18 , step =  200 , loss_val =  0.02799339
# epochs =  18 , step =  300 , loss_val =  0.04713672
# epochs =  18 , step =  400 , loss_val =  0.06517722
# epochs =  18 , step =  500 , loss_val =  0.13887925
# epochs =  19 , step =  0 , loss_val =  0.023577917
# epochs =  19 , step =  100 , loss_val =  0.004718947
# epochs =  19 , step =  200 , loss_val =  0.0697105
# epochs =  19 , step =  300 , loss_val =  0.036214665
# epochs =  19 , step =  400 , loss_val =  0.0249795
# epochs =  19 , step =  500 , loss_val =  0.027381988
# epochs =  20 , step =  0 , loss_val =  0.14551707
# epochs =  20 , step =  100 , loss_val =  0.019162806
# epochs =  20 , step =  200 , loss_val =  0.023958767
# epochs =  20 , step =  300 , loss_val =  0.032613546
# epochs =  20 , step =  400 , loss_val =  0.01697198
# epochs =  20 , step =  500 , loss_val =  0.035983868
# epochs =  21 , step =  0 , loss_val =  0.022876805
# epochs =  21 , step =  100 , loss_val =  0.013009833
# epochs =  21 , step =  200 , loss_val =  0.00800022
# epochs =  21 , step =  300 , loss_val =  0.026165776
# epochs =  21 , step =  400 , loss_val =  0.03330352
# epochs =  21 , step =  500 , loss_val =  0.014795241
# epochs =  22 , step =  0 , loss_val =  0.060945727
# epochs =  22 , step =  100 , loss_val =  0.014451585
# epochs =  22 , step =  200 , loss_val =  0.025285978
# epochs =  22 , step =  300 , loss_val =  0.013620137
# epochs =  22 , step =  400 , loss_val =  0.025913484
# epochs =  22 , step =  500 , loss_val =  0.018142631
# epochs =  23 , step =  0 , loss_val =  0.0070596323
# epochs =  23 , step =  100 , loss_val =  0.048524562
# epochs =  23 , step =  200 , loss_val =  0.026143318
# epochs =  23 , step =  300 , loss_val =  0.011974387
# epochs =  23 , step =  400 , loss_val =  0.03611182
# epochs =  23 , step =  500 , loss_val =  0.008872523
# epochs =  24 , step =  0 , loss_val =  0.0074193394
# epochs =  24 , step =  100 , loss_val =  0.026588524
# epochs =  24 , step =  200 , loss_val =  0.01989306
# epochs =  24 , step =  300 , loss_val =  0.059518386
# epochs =  24 , step =  400 , loss_val =  0.017597614
# epochs =  24 , step =  500 , loss_val =  0.0034174144
# epochs =  25 , step =  0 , loss_val =  0.017420974
# epochs =  25 , step =  100 , loss_val =  0.022216348
# epochs =  25 , step =  200 , loss_val =  0.01772922
# epochs =  25 , step =  300 , loss_val =  0.04885035
# epochs =  25 , step =  400 , loss_val =  0.056234825
# epochs =  25 , step =  500 , loss_val =  0.009344956
# epochs =  26 , step =  0 , loss_val =  0.042204488
# epochs =  26 , step =  100 , loss_val =  0.059303723
# epochs =  26 , step =  200 , loss_val =  0.017225204
# epochs =  26 , step =  300 , loss_val =  0.006695773
# epochs =  26 , step =  400 , loss_val =  0.041442882
# epochs =  26 , step =  500 , loss_val =  0.02077572
# epochs =  27 , step =  0 , loss_val =  0.008853596
# epochs =  27 , step =  100 , loss_val =  0.021972332
# epochs =  27 , step =  200 , loss_val =  0.03735479
# epochs =  27 , step =  300 , loss_val =  0.020569105
# epochs =  27 , step =  400 , loss_val =  0.01228431
# epochs =  27 , step =  500 , loss_val =  0.05510741
# epochs =  28 , step =  0 , loss_val =  0.015915608
# epochs =  28 , step =  100 , loss_val =  0.016577097
# epochs =  28 , step =  200 , loss_val =  0.031323742
# epochs =  28 , step =  300 , loss_val =  0.0042902958
# epochs =  28 , step =  400 , loss_val =  0.03135568
# epochs =  28 , step =  500 , loss_val =  0.07708661
# epochs =  29 , step =  0 , loss_val =  0.015920766
# epochs =  29 , step =  100 , loss_val =  0.071081355
# epochs =  29 , step =  200 , loss_val =  0.013059225
# epochs =  29 , step =  300 , loss_val =  0.013872084
# epochs =  29 , step =  400 , loss_val =  0.0017197737
# epochs =  29 , step =  500 , loss_val =  0.037861966
#
# elapsed time =  0:00:59.380399
#
# Accuracy =  0.9818
