# %%
# %tensorflow_version 1.x

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime


mnist = input_data.read_data_sets('MNIST_data/', one_hot=True)

print()
print("train.num = ", mnist.train.num_examples)
print("test.num = ", mnist.test.num_examples)
print("validation_num = ", mnist.validation.num_examples)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
#
# train.num =  55000
# test.num =  10000
# validation_num =  5000

# %%
learning_rate = 1e-3
epochs = 30
batch_size = 100

# %%
X = tf.placeholder(tf.float32, [None, 784])

T = tf.placeholder(tf.float32, [None, 10])

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])

# %%
W2 = tf.Variable(tf.random_normal([5, 5, 1, 32], stddev=0.01))
b2 = tf.Variable(tf.random_normal([32]))

C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

Z2 = tf.nn.relu(C2 + b2)

A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
W3 = tf.Variable(tf.random_normal([5, 5, 32, 64], stddev=0.01))
b3 = tf.Variable(tf.random_normal([64]))

C3 = tf.nn.conv2d(A2, W3, strides=[1, 1, 1, 1], padding='SAME')

Z3 = tf.nn.relu(C3 + b3)

A3 = P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
A3_flat = P3_flat = tf.reshape(A3, [-1, 7*7*64])

# %%
W4 = tf.Variable(tf.random_normal([7*7*64, 10], stddev=0.01))
b4 = tf.Variable(tf.random_normal([10]))

Z4 = logits = tf.matmul(A3_flat, W4) + b4

y = A4 = tf.nn.softmax(Z4)

# %%
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z4, labels=T))

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
predicted_val = tf.equal(tf.argmax(A4, 1), tf.argmax(T, 1))

accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# %%
with tf.Session() as sess:
  
  sess.run(tf.global_variables_initializer())

  start_time = datetime.now()

  for i in range(epochs):

    total_batch = int(mnist.train.num_examples / batch_size)

    for step in range(total_batch):

      batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)

      loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})

      if step % 100 == 0:
        print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)

  end_time = datetime.now()

  print("\nelapsed time = ", end_time - start_time)

  test_x_data = mnist.test.images
  test_t_data = mnist.test.labels

  accuracy_val = sess.run(accuracy, feed_dict={X: test_x_data, T: test_t_data})

  print("\nAccuracy = ", accuracy_val)
# Out:
# epochs =  0 , step =  0 , loss_val =  2.7374554
# epochs =  0 , step =  100 , loss_val =  1.3925151
# epochs =  0 , step =  200 , loss_val =  0.3760575
# epochs =  0 , step =  300 , loss_val =  0.15423991
# epochs =  0 , step =  400 , loss_val =  0.29267845
# epochs =  0 , step =  500 , loss_val =  0.21048722
# epochs =  1 , step =  0 , loss_val =  0.20565034
# epochs =  1 , step =  100 , loss_val =  0.16329509
# epochs =  1 , step =  200 , loss_val =  0.1406387
# epochs =  1 , step =  300 , loss_val =  0.24150637
# epochs =  1 , step =  400 , loss_val =  0.04393526
# epochs =  1 , step =  500 , loss_val =  0.054575924
# epochs =  2 , step =  0 , loss_val =  0.17747532
# epochs =  2 , step =  100 , loss_val =  0.10563744
# epochs =  2 , step =  200 , loss_val =  0.027627088
# epochs =  2 , step =  300 , loss_val =  0.049447432
# epochs =  2 , step =  400 , loss_val =  0.081074655
# epochs =  2 , step =  500 , loss_val =  0.07311464
# epochs =  3 , step =  0 , loss_val =  0.040008016
# epochs =  3 , step =  100 , loss_val =  0.018861486
# epochs =  3 , step =  200 , loss_val =  0.029675694
# epochs =  3 , step =  300 , loss_val =  0.023380622
# epochs =  3 , step =  400 , loss_val =  0.02317252
# epochs =  3 , step =  500 , loss_val =  0.07178605
# epochs =  4 , step =  0 , loss_val =  0.05999659
# epochs =  4 , step =  100 , loss_val =  0.028491346
# epochs =  4 , step =  200 , loss_val =  0.03186582
# epochs =  4 , step =  300 , loss_val =  0.053149983
# epochs =  4 , step =  400 , loss_val =  0.050328337
# epochs =  4 , step =  500 , loss_val =  0.020406911
# epochs =  5 , step =  0 , loss_val =  0.06357955
# epochs =  5 , step =  100 , loss_val =  0.022759594
# epochs =  5 , step =  200 , loss_val =  0.04285794
# epochs =  5 , step =  300 , loss_val =  0.08695804
# epochs =  5 , step =  400 , loss_val =  0.014604317
# epochs =  5 , step =  500 , loss_val =  0.027459417
# epochs =  6 , step =  0 , loss_val =  0.036135577
# epochs =  6 , step =  100 , loss_val =  0.056508183
# epochs =  6 , step =  200 , loss_val =  0.016560238
# epochs =  6 , step =  300 , loss_val =  0.06455218
# epochs =  6 , step =  400 , loss_val =  0.019087672
# epochs =  6 , step =  500 , loss_val =  0.06374058
# epochs =  7 , step =  0 , loss_val =  0.08009241
# epochs =  7 , step =  100 , loss_val =  0.024745107
# epochs =  7 , step =  200 , loss_val =  0.08218506
# epochs =  7 , step =  300 , loss_val =  0.0030207152
# epochs =  7 , step =  400 , loss_val =  0.01277892
# epochs =  7 , step =  500 , loss_val =  0.10674143
# epochs =  8 , step =  0 , loss_val =  0.11497494
# epochs =  8 , step =  100 , loss_val =  0.13174818
# epochs =  8 , step =  200 , loss_val =  0.005674994
# epochs =  8 , step =  300 , loss_val =  0.006706929
# epochs =  8 , step =  400 , loss_val =  0.02398458
# epochs =  8 , step =  500 , loss_val =  0.022238694
# epochs =  9 , step =  0 , loss_val =  0.0053066886
# epochs =  9 , step =  100 , loss_val =  0.042067766
# epochs =  9 , step =  200 , loss_val =  0.02097377
# epochs =  9 , step =  300 , loss_val =  0.09140489
# epochs =  9 , step =  400 , loss_val =  0.012225453
# epochs =  9 , step =  500 , loss_val =  0.032577373
# epochs =  10 , step =  0 , loss_val =  0.005156406
# epochs =  10 , step =  100 , loss_val =  0.06104016
# epochs =  10 , step =  200 , loss_val =  0.006469022
# epochs =  10 , step =  300 , loss_val =  0.028553896
# epochs =  10 , step =  400 , loss_val =  0.00509076
# epochs =  10 , step =  500 , loss_val =  0.017281847
# epochs =  11 , step =  0 , loss_val =  0.007313843
# epochs =  11 , step =  100 , loss_val =  0.015512797
# epochs =  11 , step =  200 , loss_val =  0.0071228067
# epochs =  11 , step =  300 , loss_val =  0.010054094
# epochs =  11 , step =  400 , loss_val =  0.04234692
# epochs =  11 , step =  500 , loss_val =  0.016554225
# epochs =  12 , step =  0 , loss_val =  0.023341615
# epochs =  12 , step =  100 , loss_val =  0.029150495
# epochs =  12 , step =  200 , loss_val =  0.049716365
# epochs =  12 , step =  300 , loss_val =  0.026628008
# epochs =  12 , step =  400 , loss_val =  0.0049189655
# epochs =  12 , step =  500 , loss_val =  0.0150989
# epochs =  13 , step =  0 , loss_val =  0.014610356
# epochs =  13 , step =  100 , loss_val =  0.021725263
# epochs =  13 , step =  200 , loss_val =  0.021961238
# epochs =  13 , step =  300 , loss_val =  0.032606207
# epochs =  13 , step =  400 , loss_val =  0.037967242
# epochs =  13 , step =  500 , loss_val =  0.03297969
# epochs =  14 , step =  0 , loss_val =  0.0103659555
# epochs =  14 , step =  100 , loss_val =  0.024932027
# epochs =  14 , step =  200 , loss_val =  0.00041840732
# epochs =  14 , step =  300 , loss_val =  0.0321704
# epochs =  14 , step =  400 , loss_val =  0.0030954918
# epochs =  14 , step =  500 , loss_val =  0.011124015
# epochs =  15 , step =  0 , loss_val =  0.0036102345
# epochs =  15 , step =  100 , loss_val =  0.009629253
# epochs =  15 , step =  200 , loss_val =  0.000955302
# epochs =  15 , step =  300 , loss_val =  0.012528106
# epochs =  15 , step =  400 , loss_val =  0.0040198774
# epochs =  15 , step =  500 , loss_val =  0.0069274814
# epochs =  16 , step =  0 , loss_val =  0.0035624208
# epochs =  16 , step =  100 , loss_val =  0.0024580564
# epochs =  16 , step =  200 , loss_val =  0.016403038
# epochs =  16 , step =  300 , loss_val =  0.026121208
# epochs =  16 , step =  400 , loss_val =  0.009863757
# epochs =  16 , step =  500 , loss_val =  0.0359297
# epochs =  17 , step =  0 , loss_val =  0.009359866
# epochs =  17 , step =  100 , loss_val =  0.0004025493
# epochs =  17 , step =  200 , loss_val =  0.00081561215
# epochs =  17 , step =  300 , loss_val =  0.000838189
# epochs =  17 , step =  400 , loss_val =  0.012793361
# epochs =  17 , step =  500 , loss_val =  0.007888999
# epochs =  18 , step =  0 , loss_val =  0.0065857647
# epochs =  18 , step =  100 , loss_val =  0.0037959265
# epochs =  18 , step =  200 , loss_val =  0.040819775
# epochs =  18 , step =  300 , loss_val =  0.0020912816
# epochs =  18 , step =  400 , loss_val =  0.009366986
# epochs =  18 , step =  500 , loss_val =  0.054083835
# epochs =  19 , step =  0 , loss_val =  0.00444735
# epochs =  19 , step =  100 , loss_val =  0.0014763549
# epochs =  19 , step =  200 , loss_val =  0.0036296782
# epochs =  19 , step =  300 , loss_val =  0.00644732
# epochs =  19 , step =  400 , loss_val =  0.0056105866
# epochs =  19 , step =  500 , loss_val =  0.003451776
# epochs =  20 , step =  0 , loss_val =  0.0057760715
# epochs =  20 , step =  100 , loss_val =  0.0021552434
# epochs =  20 , step =  200 , loss_val =  0.0008643736
# epochs =  20 , step =  300 , loss_val =  0.0012529638
# epochs =  20 , step =  400 , loss_val =  0.0021525281
# epochs =  20 , step =  500 , loss_val =  0.0070994035
# epochs =  21 , step =  0 , loss_val =  0.0031742984
# epochs =  21 , step =  100 , loss_val =  0.0012454162
# epochs =  21 , step =  200 , loss_val =  0.0019917563
# epochs =  21 , step =  300 , loss_val =  0.00032423608
# epochs =  21 , step =  400 , loss_val =  0.002373696
# epochs =  21 , step =  500 , loss_val =  0.0065218676
# epochs =  22 , step =  0 , loss_val =  0.0024483728
# epochs =  22 , step =  100 , loss_val =  0.00678128
# epochs =  22 , step =  200 , loss_val =  0.024048723
# epochs =  22 , step =  300 , loss_val =  0.0013204777
# epochs =  22 , step =  400 , loss_val =  0.0049316324
# epochs =  22 , step =  500 , loss_val =  0.016689053
# epochs =  23 , step =  0 , loss_val =  0.018801713
# epochs =  23 , step =  100 , loss_val =  0.00222459
# epochs =  23 , step =  200 , loss_val =  0.0002643947
# epochs =  23 , step =  300 , loss_val =  0.0017315627
# epochs =  23 , step =  400 , loss_val =  0.007954899
# epochs =  23 , step =  500 , loss_val =  0.0008345855
# epochs =  24 , step =  0 , loss_val =  0.004648049
# epochs =  24 , step =  100 , loss_val =  0.00025045522
# epochs =  24 , step =  200 , loss_val =  0.00025051445
# epochs =  24 , step =  300 , loss_val =  0.006070854
# epochs =  24 , step =  400 , loss_val =  0.011046151
# epochs =  24 , step =  500 , loss_val =  0.012241629
# epochs =  25 , step =  0 , loss_val =  0.0060225655
# epochs =  25 , step =  100 , loss_val =  0.00017745906
# epochs =  25 , step =  200 , loss_val =  0.00041333557
# epochs =  25 , step =  300 , loss_val =  0.0048345802
# epochs =  25 , step =  400 , loss_val =  0.0062883683
# epochs =  25 , step =  500 , loss_val =  0.0137011465
# epochs =  26 , step =  0 , loss_val =  0.0064003747
# epochs =  26 , step =  100 , loss_val =  0.022914208
# epochs =  26 , step =  200 , loss_val =  0.0011754134
# epochs =  26 , step =  300 , loss_val =  0.010424401
# epochs =  26 , step =  400 , loss_val =  0.00016030445
# epochs =  26 , step =  500 , loss_val =  0.0018925401
# epochs =  27 , step =  0 , loss_val =  0.053084917
# epochs =  27 , step =  100 , loss_val =  0.038590338
# epochs =  27 , step =  200 , loss_val =  0.01580819
# epochs =  27 , step =  300 , loss_val =  0.010281893
# epochs =  27 , step =  400 , loss_val =  0.0009294225
# epochs =  27 , step =  500 , loss_val =  0.0018861208
# epochs =  28 , step =  0 , loss_val =  0.0028628132
# epochs =  28 , step =  100 , loss_val =  0.0024290627
# epochs =  28 , step =  200 , loss_val =  0.0002778773
# epochs =  28 , step =  300 , loss_val =  0.0025335727
# epochs =  28 , step =  400 , loss_val =  0.00011657768
# epochs =  28 , step =  500 , loss_val =  0.0047262805
# epochs =  29 , step =  0 , loss_val =  0.00012349234
# epochs =  29 , step =  100 , loss_val =  0.00032260397
# epochs =  29 , step =  200 , loss_val =  0.00020644117
# epochs =  29 , step =  300 , loss_val =  0.03895317
# epochs =  29 , step =  400 , loss_val =  0.00013091766
# epochs =  29 , step =  500 , loss_val =  0.034234043
#
# elapsed time =  0:01:13.159434
#
# Accuracy =  0.9862
